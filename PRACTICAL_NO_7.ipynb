# %% [markdown]
# <a href="https://colab.research.google.com/github/KrutiTaware/Data-Science-Pratical/blob/Master/PRACTICAL_NO_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame(
    {"Roll no.":[6221,6222,6223,6224,6225,6226,6227,6228,6229,6230],
     "Name":['Suraj','Gargi','Swathi','Kruti','Teesha','Sambhavi','Sayali','Prathmesh','Gargi','Sahil'],
     "Marks":[18,19,19,18,17,19,18,16,15,19]})
df
# Out:
#    Roll no.       Name  Marks
# 0      6221      Suraj     18
# 1      6222      Gargi     19
# 2      6223     Swathi     19
# 3      6224      Kruti     18
# 4      6225     Teesha     17
# 5      6226   Sambhavi     19
# 6      6227     Sayali     18
# 7      6228  Prathmesh     16
# 8      6229      Gargi     15
# 9      6230      Sahil     19

# %%
#Check for null values
df.isnull()
# Out:
#    Roll no.   Name  Marks
# 0     False  False  False
# 1     False  False  False
# 2     False  False  False
# 3     False  False  False
# 4     False  False  False
# 5     False  False  False
# 6     False  False  False
# 7     False  False  False
# 8     False  False  False
# 9     False  False  False

# %%
# Generate Descriptive Statistics for Numeric Columns
df.describe()
# Out:
#          Roll no.      Marks
# count    10.00000  10.000000
# mean   6225.50000  17.800000
# std       3.02765   1.398412
# min    6221.00000  15.000000
# 25%    6223.25000  17.250000
# 50%    6225.50000  18.000000
# 75%    6227.75000  19.000000
# max    6230.00000  19.000000

# %%
df.describe(include='object')
# Out:
#          Name
# count      10
# unique      9
# top     Gargi
# freq        2

# %%
# Display the Shape
df.shape
# Out:
# (10, 3)

# %%
#Display Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Roll no.  10 non-null     int64
#  1   Name      10 non-null     object
#  2   Marks     10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 368.0+ bytes

# %%
# Count the Number of Unique Values in Each Column
df.nunique()
# Out:
# Roll no.    10
# Name         9
# Marks        5
# dtype: int64

# %%
# Check for Duplicated Rows in the DataFrame
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
# Count the Number of Duplicated Rows
df.duplicated().sum()
# Out:
# 0

# %%
# Count the Occurrences of Unique Rows
df.value_counts()
# Out:
# Roll no.  Name       Marks
# 6221      Suraj      18       1
# 6222      Gargi      19       1
# 6223      Swathi     19       1
# 6224      Kruti      18       1
# 6225      Teesha     17       1
# 6226      Sambhavi   19       1
# 6227      Sayali     18       1
# 6228      Prathmesh  16       1
# 6229      Gargi      15       1
# 6230      Sahil      19       1
# dtype: int64

# %%
# Count the Occurrences of Each Unique Name in the 'Name' Column
df['Name'].value_counts()
# Out:
# Gargi        2
# Suraj        1
# Swathi       1
# Kruti        1
# Teesha       1
# Sambhavi     1
# Sayali       1
# Prathmesh    1
# Sahil        1
# Name: Name, dtype: int64

# %%
# Calculate the Variance for Each Column
df.var()
# Out:
# <ipython-input-9-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Roll no.    9.166667
# Marks       1.955556
# dtype: float64

# %%
# Calculate the Mean for Each Column
df.mean()
# Out:
# <ipython-input-8-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Roll no.    6225.5
# Marks         17.8
# dtype: float64

# %%
# Calculate the Variance for the 'Marks' Column
df['Marks'].var()
# Out:
# 1.9555555555555553

# %%
# Calculate the Covariance Matrix
df.cov()
# Out:
# <ipython-input-7-e97ed96b4d33>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()  #covariance
#           Roll no.     Marks
# Roll no.  9.166667 -1.777778
# Marks    -1.777778  1.955556

# %%
# Calculate the Correlation Matrix
df.corr()
# Out:
# <ipython-input-26-3e4f44761687>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Roll no.     Marks
# Roll no.  1.000000 -0.419891
# Marks    -0.419891  1.000000

# %%
# Calculate the Correlation Matrix
correlation=df.corr()
# Out:
# <ipython-input-27-057b51433466>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True,fmt='.3f',cmap='viridis')
# Out:
# <Axes: >
