# %% [markdown]
# <a href="https://colab.research.google.com/github/KrutiTaware/Data-Science-Pratical/blob/Master/Practical_no_7(Data%20Science).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('C:\Users\Student\Desktop/Zomato Dataset')
df
# Out:
#   File "<ipython-input-1-1ef09f9d1a57>", line 2
#     df=pd.read_csv('C:\Users\Student\Desktop/Zomato Dataset')
#                                                             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
df=pd.read_excel('/content/Zomato dataset.xlsx')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730            NamlÃ›Â± Gurme           208       Ã›Ãstanbul
# 9547        5908749         Ceviz AÃ›Ã´acÃ›Â±           208       Ã›Ãstanbul
# 9548        5915807                     Huqqa           208       Ã›Ãstanbul
# 9549        5916112        Aï¿½Ã´ï¿½Ã´k Kahve           208       Ã›Ãstanbul
# 9550        5927402  Walter's Coffee Roastery           208       Ã›Ãstanbul
#
# ...

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img=mpimg.imread('/content/Zomato Dataset.jpg')
plt.imshow(img)

# %%
import pandas as pd
df=pd.DataFrame(
    {"Roll no.":[6221,6222,6223,6224,6225,6226,6227,6228,6229,6230],
     "Name":['Suraj','Gargi','Swathi','Kruti','Teesha','Sambhavi','Sayali','Prathmesh','Gargi','Sahil'],
     "Marks":[18,19,19,18,17,19,18,16,15,19]}
)
df
# Out:
#    Roll no.       Name  Marks
# 0      6221      Suraj     18
# 1      6222      Gargi     19
# 2      6223     Swathi     19
# 3      6224      Kruti     18
# 4      6225     Teesha     17
# 5      6226   Sambhavi     19
# 6      6227     Sayali     18
# 7      6228  Prathmesh     16
# 8      6229      Gargi     15
# 9      6230      Sahil     19

# %%
df.isnull()
# Out:
#    Roll no.   Name  Marks
# 0     False  False  False
# 1     False  False  False
# 2     False  False  False
# 3     False  False  False
# 4     False  False  False
# 5     False  False  False
# 6     False  False  False
# 7     False  False  False
# 8     False  False  False
# 9     False  False  False

# %%
df.describe(include='object')
# Out:
#          Name
# count      10
# unique      9
# top     Gargi
# freq        2

# %%
df.shape
# Out:
# (10, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Roll no.  10 non-null     int64
#  1   Name      10 non-null     object
#  2   Marks     10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 368.0+ bytes

# %%
df.nunique()
# Out:
# Roll no.    10
# Name         9
# Marks        5
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.value_counts()
# Out:
# Roll no.  Name       Marks
# 6221      Suraj      18       1
# 6222      Gargi      19       1
# 6223      Swathi     19       1
# 6224      Kruti      18       1
# 6225      Teesha     17       1
# 6226      Sambhavi   19       1
# 6227      Sayali     18       1
# 6228      Prathmesh  16       1
# 6229      Gargi      15       1
# 6230      Sahil      19       1
# dtype: int64

# %%
df['Name'].value_counts()
# Out:
# Gargi        2
# Suraj        1
# Swathi       1
# Kruti        1
# Teesha       1
# Sambhavi     1
# Sayali       1
# Prathmesh    1
# Sahil        1
# Name: Name, dtype: int64

# %%
correlation=df.corr()
# Out:
# <ipython-input-12-0c9b4bd1cb53>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True,fmt='.3f',cmap='viridis')
# Out:
# <Axes: >

# %%
df.var()
# Out:
# <ipython-input-15-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Roll no.    9.166667
# Marks       1.955556
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-14-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Roll no.    6225.5
# Marks         17.8
# dtype: float64

# %%
df['Marks'].var()
# Out:
# 1.9555555555555553

# %%
df.cov()  #covariance
# Out:
# <ipython-input-17-e97ed96b4d33>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()  #covariance
#           Roll no.     Marks
# Roll no.  9.166667 -1.777778
# Marks    -1.777778  1.955556

# %%
df.corr()
# Out:
# <ipython-input-18-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Roll no.     Marks
# Roll no.  1.000000 -0.419891
# Marks    -0.419891  1.000000
